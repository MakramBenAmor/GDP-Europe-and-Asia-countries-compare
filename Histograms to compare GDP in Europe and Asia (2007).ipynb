# %% [markdown]
# # 1St problem: compare Europe and Asia GDP (2007)

# %%
import pandas as pd 
from matplotlib import pyplot as plt 
data= pd.read_csv("countries.csv")
data
# Out:
#           country continent  year  lifeExpectancy  population  gdpPerCapita
# 0     Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1     Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2     Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3     Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4     Afghanistan      Asia  1972          36.088    13079460    739.981106
# ...           ...       ...   ...             ...         ...           ...
# 1699     Zimbabwe    Africa  1987          62.351     9216418    706.157306
# 1700     Zimbabwe    Africa  1992          60.377    10704340    693.420786
# 1701     Zimbabwe    Africa  1997          46.809    11404948    792.449960
# 1702     Zimbabwe    Africa  2002          39.989    11926563    672.038623
# 1703     Zimbabwe    Africa  2007          43.487    12311143    469.709298
#
# [1704 rows x 6 columns]

# %%
set(data.continent)
# Out:
# {'Africa', 'Americas', 'Asia', 'Europe', 'Oceania'}

# %%
data_2007=data[data.year== 2007]

# %%
asia_data_2007=data_2007[data_2007.continent=="Asia"]
Europe_data_2007=data_2007[data_2007.continent=="Europe"]

# %%
len(set(asia_data_2007.country))
# Out:
# 33

# %%
len(set(Europe_data_2007.country))
# Out:
# 30

# %%
print("Mean GDP per Capita in Asia: ")
print(asia_data_2007.gdpPerCapita.mean())

print("Mean GDP per Capita in Europe: ")
print(Europe_data_2007.gdpPerCapita.mean())

print("Median GDP per Capita in Asia: ")
print(asia_data_2007.gdpPerCapita.median())

print("Median GDP per Capita in Europe: ")
print(Europe_data_2007.gdpPerCapita.median())
# Out:
# Mean GDP per Capita in Asia:
# 12473.02687013333
# Mean GDP per Capita in Europe:
# 25054.481635933327
# Median GDP per Capita in Asia:
# 4471.061906
# Median GDP per Capita in Europe:
# 28054.06579

# %%
plt.subplot(211)
plt.hist(asia_data_2007.gdpPerCapita, range=(0,50000) ,edgecolor= "black")
plt.ylabel("Asia")
plt.subplot(212)
plt.ylabel("Europe")
plt.hist(Europe_data_2007.gdpPerCapita, range=(0,50000),edgecolor= "red")
plt.show()

# %% [markdown]
# ### Histograms show that Europe have more countries with high and medium GDp, unlike Asia where most countries with low GDp

# %% [markdown]
# # 2nd problem: compare Europe and Americas life expectency

# %%
americas=data[data.continent=="Americas"]
Europe=data[data.continent=="Europe"]
americas_1997=americas[americas.year== 1997]
Europe_1997=Europe[Europe.year== 1997]
# Out:
#                   country continent  year  lifeExpectancy  population  \
# 57              Argentina  Americas  1997          73.275    36203463
# 141               Bolivia  Americas  1997          62.050     7693188
# 177                Brazil  Americas  1997          69.388   168546719
# 249                Canada  Americas  1997          78.610    30305843
# 285                 Chile  Americas  1997          75.816    14599929
# 309              Colombia  Americas  1997          70.313    37657830
# 357            Costa Rica  Americas  1997          77.260     3518107
# 393                  Cuba  Americas  1997          76.151    10983007
# 441    Dominican Republic  Americas  1997          69.957     7992357
# 453               Ecuador  Americas  1997          72.312    11911819
# 477           El Salvador  Americas  1997          69.535     5783439
# 609             Guatemala  Americas  1997          66.322     9803875
# ...

# %%
bins=20
plt.subplot(211)
plt.hist(americas_1997.lifeExpectancy , bins, range=(55,85), edgecolor="black")
plt.ylabel("Americas")
plt.subplot(212)
plt.hist(Europe_1997.lifeExpectancy , bins, range=(55,85), edgecolor="black")
plt.ylabel("Europe")
plt.show()

# %%
#we want to know which are the 2 countries with Life Expectency below the 65 year
americas_1997[americas_1997.lifeExpectancy < 65]
# Out:
#      country continent  year  lifeExpectancy  population  gdpPerCapita
# 141  Bolivia  Americas  1997          62.050     7693188   3326.143191
# 645    Haiti  Americas  1997          56.671     6913545   1341.726931
